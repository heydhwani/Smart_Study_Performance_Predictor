# %%
import pandas as pd

df = pd.read_csv("../dataset/student_habits_performance.csv")
df.head()
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5            No                   90.9          4.9
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# ...

# %%
df.shape
# Out:
# (1000, 16)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   str
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   str
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   str
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   str
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       909 non-null    str
#  12  internet_quality               1000 non-null   str
# ...

# %%
df.describe()
# Out:
#              age  study_hours_per_day  social_media_hours  netflix_hours  \
# count  1000.0000           1000.00000         1000.000000    1000.000000
# mean     20.4980              3.55010            2.505500       1.819700
# std       2.3081              1.46889            1.172422       1.075118
# min      17.0000              0.00000            0.000000       0.000000
# 25%      18.7500              2.60000            1.700000       1.000000
# 50%      20.0000              3.50000            2.500000       1.800000
# 75%      23.0000              4.50000            3.300000       2.525000
# max      24.0000              8.30000            7.200000       5.400000
#
#        attendance_percentage  sleep_hours  exercise_frequency  \
# count            1000.000000  1000.000000         1000.000000
# mean               84.131700     6.470100            3.042000
# std                 9.399246     1.226377            2.025423
# ...

# %%
df.isnull().sum()
# Out:
# student_id                        0
# age                               0
# gender                            0
# study_hours_per_day               0
# social_media_hours                0
# netflix_hours                     0
# part_time_job                     0
# attendance_percentage             0
# sleep_hours                       0
# diet_quality                      0
# exercise_frequency                0
# parental_education_level         91
# internet_quality                  0
# mental_health_rating              0
# extracurricular_participation     0
# exam_score                        0
# dtype: int64

# %%
df["parental_education_level"] = df["parental_education_level"].fillna(
    df["parental_education_level"].mode()[0]
)

# %%
df.isnull().sum()
# Out:
# student_id                       0
# age                              0
# gender                           0
# study_hours_per_day              0
# social_media_hours               0
# netflix_hours                    0
# part_time_job                    0
# attendance_percentage            0
# sleep_hours                      0
# diet_quality                     0
# exercise_frequency               0
# parental_education_level         0
# internet_quality                 0
# mental_health_rating             0
# extracurricular_participation    0
# exam_score                       0
# dtype: int64

# %%
df = df.drop(columns=["student_id"])

# %%
df.head()
# Out:
#    age  gender  study_hours_per_day  social_media_hours  netflix_hours  \
# 0   23  Female                  0.0                 1.2            1.1
# 1   20  Female                  6.9                 2.8            2.3
# 2   21    Male                  1.4                 3.1            1.3
# 3   23  Female                  1.0                 3.9            1.0
# 4   19  Female                  5.0                 4.4            0.5
#
#   part_time_job  attendance_percentage  sleep_hours diet_quality  \
# 0            No                   85.0          8.0         Fair
# 1            No                   97.3          4.6         Good
# 2            No                   94.8          8.0         Poor
# 3            No                   71.0          9.2         Poor
# 4            No                   90.9          4.9         Fair
#
#    exercise_frequency parental_education_level internet_quality  \
# 0                   6                   Master          Average
# ...

# %%
df.columns
# Out:
# Index(['age', 'gender', 'study_hours_per_day', 'social_media_hours',
#        'netflix_hours', 'part_time_job', 'attendance_percentage',
#        'sleep_hours', 'diet_quality', 'exercise_frequency',
#        'parental_education_level', 'internet_quality', 'mental_health_rating',
#        'extracurricular_participation', 'exam_score'],
#       dtype='str')

# %%
def performance_category(score):
    if score >= 85:
        return "Excellent"
    elif score >= 70:
        return "Good"
    elif score >= 50:
        return "Average"
    else:
        return "Poor"

df["performance"] = df["exam_score"].apply(performance_category)

# %%
df[["exam_score", "performance"]].head()
# Out:
#    exam_score performance
# 0        56.2     Average
# 1       100.0   Excellent
# 2        34.3        Poor
# 3        26.8        Poor
# 4        66.4     Average

# %%
df["performance"].value_counts()
# Out:
# performance
# Average      358
# Good         323
# Excellent    188
# Poor         131
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()

categorical_columns = df.select_dtypes(include=["object", "string"]).columns

for column in categorical_columns:
    df[column] = label_encoder.fit_transform(df[column])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   age                            1000 non-null   int64
#  1   gender                         1000 non-null   int64
#  2   study_hours_per_day            1000 non-null   float64
#  3   social_media_hours             1000 non-null   float64
#  4   netflix_hours                  1000 non-null   float64
#  5   part_time_job                  1000 non-null   int64
#  6   attendance_percentage          1000 non-null   float64
#  7   sleep_hours                    1000 non-null   float64
#  8   diet_quality                   1000 non-null   int64
#  9   exercise_frequency             1000 non-null   int64
#  10  parental_education_level       1000 non-null   int64
#  11  internet_quality               1000 non-null   int64
# ...

# %% [markdown]
# # Data Splitting and Feature Scaling
#
# Before training the machine learning models, the dataset is divided into training and testing sets.
#
# - **Training Set (80%)**: Used to train the models.
# - **Testing Set (20%)**: Used to evaluate model performance.
# - **StandardScaler** is applied to normalize the feature values.

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Preparing Data for Regression
#
# For regression, the target variable is **exam_score**.

# %%
X_reg = df.drop(columns=["exam_score", "performance"])
y_reg = df["exam_score"]

X_train_reg, X_test_reg, y_train_reg, y_test_reg = train_test_split(
    X_reg,
    y_reg,
    test_size=0.2,
    random_state=42
)

# %% [markdown]
# ## Preparing Data for Classification
#
# For classification, the target variable is **performance**.

# %%
X_clf = df.drop(columns=["exam_score", "performance"])
y_clf = df["performance"]

X_train_clf, X_test_clf, y_train_clf, y_test_clf = train_test_split(
    X_clf,
    y_clf,
    test_size=0.2,
    random_state=42
)

# %% [markdown]
# ## Feature Scaling
#
# Feature scaling is performed using **StandardScaler** to ensure that numerical features have a similar scale. This helps improve the performance of machine learning algorithms.

# %%
scaler_reg = StandardScaler()

X_train_reg = scaler_reg.fit_transform(X_train_reg)
X_test_reg = scaler_reg.transform(X_test_reg)

scaler_clf = StandardScaler()

X_train_clf = scaler_clf.fit_transform(X_train_clf)
X_test_clf = scaler_clf.transform(X_test_clf)

# %% [markdown]
# ## Verifying Dataset Shapes
#
# The following code checks the dimensions of the training and testing datasets for both regression and classification tasks.

# %%
print("Regression Training Shape :", X_train_reg.shape)
print("Regression Testing Shape  :", X_test_reg.shape)

print()

print("Classification Training Shape :", X_train_clf.shape)
print("Classification Testing Shape  :", X_test_clf.shape)
# Out:
# Regression Training Shape : (800, 14)
# Regression Testing Shape  : (200, 14)
#
# Classification Training Shape : (800, 14)
# Classification Testing Shape  : (200, 14)

# %% [markdown]
# # Regression Model
#
# In this section, a **Random Forest Regressor** is trained to predict students' exam scores.
#
# Random Forest is an ensemble learning algorithm that combines multiple decision trees to improve prediction accuracy and reduce overfitting.

# %%
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# ## Model Training
#
# The regression model is trained using the training dataset.

# %%
regressor = RandomForestRegressor(
    n_estimators=100,
    random_state=42
)

regressor.fit(X_train_reg, y_train_reg)
# Out:
# RandomForestRegressor(random_state=42)

# %% [markdown]
# ## Model Prediction
#
# The trained model is used to predict exam scores for the testing dataset.

# %%
y_pred_reg = regressor.predict(X_test_reg)

# %% [markdown]
# ## Regression Model Evaluation
#
# The performance of the regression model is evaluated using:
#
# - R² Score
# - Mean Absolute Error (MAE)
# - Root Mean Squared Error (RMSE)

# %%
from sklearn.metrics import (
    r2_score,
    mean_absolute_error,
    root_mean_squared_error
)

r2 = r2_score(y_test_reg, y_pred_reg)
mae = mean_absolute_error(y_test_reg, y_pred_reg)
rmse = root_mean_squared_error(y_test_reg, y_pred_reg)

print(f"R² Score : {r2:.4f}")
print(f"MAE      : {mae:.4f}")
print(f"RMSE     : {rmse:.4f}")
# Out:
# R² Score : 0.8491
# MAE      : 4.9507
# RMSE     : 6.2211

# %% [markdown]
# ## Actual vs Predicted Exam Scores
#
# This visualization compares the actual exam scores with the predicted scores. A good regression model should produce points close to the diagonal line.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))

plt.scatter(y_test_reg, y_pred_reg, alpha=0.7)

plt.plot(
    [y_test_reg.min(), y_test_reg.max()],
    [y_test_reg.min(), y_test_reg.max()],
    color="red",
    linestyle="--",
    linewidth=2
)

plt.xlabel("Actual Exam Score")
plt.ylabel("Predicted Exam Score")
plt.title("Actual vs Predicted Exam Scores")

plt.grid(alpha=0.3)

plt.show()

# %% [markdown]
# ### Observation
#
# The scatter plot shows that most predicted exam scores lie close to the diagonal reference line.
#
# This indicates that the Random Forest Regressor is able to predict student exam scores with good accuracy. Although a few outliers are present, the overall prediction trend closely matches the actual values, demonstrating strong model performance.

# %% [markdown]
# ## Feature Importance
#
# Feature importance helps identify which input variables have the greatest influence on predicting student exam scores.

# %%
importance = pd.DataFrame({
    "Feature": X_reg.columns,
    "Importance": regressor.feature_importances_
})

importance = importance.sort_values(
    by="Importance",
    ascending=False
)

importance
# Out:
#                           Feature  Importance
# 2             study_hours_per_day    0.707860
# 12           mental_health_rating    0.106127
# 3              social_media_hours    0.038658
# 7                     sleep_hours    0.037902
# 4                   netflix_hours    0.034999
# 9              exercise_frequency    0.025381
# 6           attendance_percentage    0.020254
# 0                             age    0.009084
# 10       parental_education_level    0.004272
# 8                    diet_quality    0.004178
# 11               internet_quality    0.003939
# 1                          gender    0.003080
# 5                   part_time_job    0.002186
# 13  extracurricular_participation    0.002080

# %% [markdown]
# ### Observation
#
# The feature importance analysis shows that **study_hours_per_day** is the most influential factor in predicting students' exam scores.
#
# Other important features include **mental_health_rating**, **social_media_hours**, **sleep_hours**, and **netflix_hours**.
#
# This suggests that both academic habits and lifestyle factors play a significant role in determining student performance.

# %%
plt.figure(figsize=(10,6))

plt.barh(
    importance["Feature"],
    importance["Importance"]
)

plt.xlabel("Importance Score")
plt.ylabel("Features")
plt.title("Feature Importance - Random Forest Regressor")

plt.gca().invert_yaxis()

plt.grid(axis="x", linestyle="--", alpha=0.5)

plt.tight_layout()

plt.show()

# %% [markdown]
# # Regression Model Summary
#
# The Random Forest Regressor demonstrated strong predictive performance with an **R² Score of 0.8491**, indicating that the model explains approximately **85% of the variance** in students' exam scores.
#
# The model achieved low prediction errors and identified **study hours per day** as the most influential feature, followed by **mental health rating**, **social media usage**, and **sleep hours**.
#
# Overall, the regression model is reliable for predicting academic performance based on students' study habits and lifestyle factors.

# %% [markdown]
# # Classification Model
#
# In this section, a **Random Forest Classifier** is trained to classify students into different performance categories based on their academic and lifestyle factors.

# %%
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ## Model Training
#
# A Random Forest Classifier is trained using the training dataset to classify students into different performance categories.

# %%
classifier = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)

classifier.fit(X_train_clf, y_train_clf)
# Out:
# RandomForestClassifier(random_state=42)

# %% [markdown]
# ## Model Prediction
#
# The trained Random Forest Classifier is used to predict the performance category of students in the testing dataset.

# %%
y_pred_clf = classifier.predict(X_test_clf)
